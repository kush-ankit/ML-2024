# %%
import numpy as np
import pandas as pd

# %%
data={
    'A':[1,2,3,4],
    'B':[5,6,7,8],
    'C':[9,10,11,12]
}
print(data)
# Out:
# {'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#    A  B   C
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
df.loc[0:2,['A','C']]
# Out:
#    A   C
# 0  1   9
# 1  2  10
# 2  3  11

# %%
df.iloc[0:2,[0,2]]
# Out:
#    A   C
# 0  1   9
# 1  2  10

# %%
df[df['A']>2]
# Out:
#    A  B   C
# 2  3  7  11
# 3  4  8  12

# %%
df.describe()
# Out:
#               A         B          C
# count  4.000000  4.000000   4.000000
# mean   2.500000  6.500000  10.500000
# std    1.290994  1.290994   1.290994
# min    1.000000  5.000000   9.000000
# 25%    1.750000  5.750000   9.750000
# 50%    2.500000  6.500000  10.500000
# 75%    3.250000  7.250000  11.250000
# max    4.000000  8.000000  12.000000

# %%
df['D']=df['A']+df['B']
print(df)
# Out:
#    A  B   C   D
# 0  1  5   9   6
# 1  2  6  10   8
# 2  3  7  11  10
# 3  4  8  12  12

# %%
df.at[0,'A']=100
df
# Out:
#      A  B   C   D
# 0  100  5   9   6
# 1    2  6  10   8
# 2    3  7  11  10
# 3    4  8  12  12

# %%
df.iat[0,2]=200
df
# Out:
#      A  B    C   D
# 0  100  5  200   6
# 1    2  6   10   8
# 2    3  7   11  10
# 3    4  8   12  12

# %%
df.loc[df['A']>2,'B'] =99
df
# Out:
#      A   B    C   D
# 0  100  99  200   6
# 1    2   6   10   8
# 2    3  99   11  10
# 3    4  99   12  12

# %%
new_df=df.copy()
new_df.iloc[0,1]=np.nan
new_df
# Out:
#      A     B    C   D
# 0  100   NaN  200   6
# 1    2   6.0   10   8
# 2    3  99.0   11  10
# 3    4  99.0   12  12

# %%
new_df.fillna(0)
# Out:
#      A     B    C   D
# 0  100   0.0  200   6
# 1    2   6.0   10   8
# 2    3  99.0   11  10
# 3    4  99.0   12  12

# %%
new_df.dropna()
# Out:
#    A     B   C   D
# 1  2   6.0  10   8
# 2  3  99.0  11  10
# 3  4  99.0  12  12

# %%
new_df.isna()
# Out:
#        A      B      C      D
# 0  False   True  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False

# %%
df.mean()
# Out:
# A    27.25
# B    75.75
# C    58.25
# D     9.00
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0    101.25
# 1      6.50
# 2     30.75
# 3     31.75
# dtype: float64

# %%
df.apply(np.cumsum)
# Out:
#      A    B    C   D
# 0  100   99  200   6
# 1  102  105  210  14
# 2  105  204  221  24
# 3  109  303  233  36

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# A     98
# B     93
# C    190
# D      6
# dtype: int64

# %%
dfstr=pd.DataFrame({'A':['foo','bar','baz'],'B':['one','two','three']})
dfstr['A'].str.upper()
# Out:
# 0    FOO
# 1    BAR
# 2    BAZ
# Name: A, dtype: object

# %%
dfstr['A'].str.len()
# Out:
# 0    3
# 1    3
# 2    3
# Name: A, dtype: int64

# %%
dfstr['A'].str.contains('o')
# Out:
# 0     True
# 1    False
# 2    False
# Name: A, dtype: bool

# %%
s1=pd.Series([1,2,3,4,5])
s2=pd.Series([6,7,8,9,10])
print(s1)
print(s2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
df1=pd.DataFrame({'A':s1,'B':s2})
df1
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
df1.dtypes
# Out:
# A    int64
# B    int64
# dtype: object

# %%
df1=pd.DataFrame({'key':['A','B','C'],'value':[1,2,3]})
df2=pd.DataFrame({'key':['B','C','D'],'value':[3,4,5]})
print(df1)
print(df2)
print(pd.merge(df1,df2,on='key',how='left'))
print(pd.merge(df1,df2,on='key',how='right'))
print(pd.merge(df1,df2,on='key',how='outer'))
print(pd.merge(df1,df2,on='key',how='inner'))
# Out:
#   key  value
# 0   A      1
# 1   B      2
# 2   C      3
#   key  value
# 0   B      3
# 1   C      4
# 2   D      5
#   key  value_x  value_y
# 0   A        1      NaN
# 1   B        2      3.0
# 2   C        3      4.0
#   key  value_x  value_y
# 0   B      2.0        3
# 1   C      3.0        4
# 2   D      NaN        5
#   key  value_x  value_y
# 0   A      1.0      NaN
# 1   B      2.0      3.0
# 2   C      3.0      4.0
# 3   D      NaN      5.0
#   key  value_x  value_y
# 0   B        2        3
# 1   C        3        4

# %%
dfgroup = pd.DataFrame({'key':['A','B','C','D'],'data':range(4)})
dfgroup
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   D     3

# %%
grouped=dfgroup.groupby('key')
grouped.sum()
# Out:
#      data
# key
# A       0
# B       1
# C       2
# D       3

# %%
grouped.mean()
# Out:
#      data
# key
# A     0.0
# B     1.0
# C     2.0
# D     3.0

# %%
grouped.size()
# Out:
# key
# A    1
# B    1
# C    1
# D    1
# dtype: int64

# %%
# prompt: create dataFrame for pivot table

dfpivot = pd.DataFrame({'date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
                       'city': ['New York', 'Los Angeles', 'New York', 'Los Angeles'],
                       'sales': [100, 150, 120, 180]})
pivot=dfpivot.pivot_table(index='date',columns='city',values='sales',aggfunc='sum')
pivot
# Out:
# city        Los Angeles  New York
# date
# 2023-01-01          150       100
# 2023-01-02          180       120
