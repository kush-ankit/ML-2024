# %%
import pandas as pd
import numpy as np
import sqlite3
import random

# %%
dfwindow = pd.DataFrame({
    'A': np.random.randn(10),
    'B': np.random.randn(10),
})

print(dfwindow['A'])
print(' ')

print(dfwindow['A'].rolling(window=3).mean())
# Out:
# 0   -0.899528
# 1    1.639692
# 2    0.352538
# 3   -0.344307
# 4   -0.105408
# 5    1.819229
# 6   -1.114811
# 7   -0.541533
# 8    0.549790
# 9    0.366132
# Name: A, dtype: float64
#
# 0         NaN
# 1         NaN
# 2    0.364234
# 3    0.549308
# 4   -0.032392
# 5    0.456504
# 6    0.199670
# 7    0.054295
# 8   -0.368851
# 9    0.124797
# Name: A, dtype: float64

# %%
dfCat = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar'],
    'B': ['small', 'large', 'small', 'large'],
})

dfCat['A'] = dfCat['A'].astype('category')
dfCat['B'] = dfCat['B'].astype('category')

print(dfCat.sort_values(by=['A','B'],ascending=False))
# Out:
#      A      B
# 0  foo  small
# 2  foo  small
# 1  bar  large
# 3  bar  large

# %%
# prompt: generate data of 5 people

import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
        'Age': [25, 30, 28, 22, 35],
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   28      Chicago
# 3    David   22      Houston
# 4    Emily   35        Miami

# %% [markdown]
# ##CSV FILE

# %%
df=pd.read_csv('c_complex_data.csv')
df
# Out:
#                 Name          Age Gender   Salary      Address    Country  \
# 0      Michael Brown      Unknown      F  60000.0      Unknown        USA
# 1        David White           28      F  70000.0   456 Elm St        NaN
# 2      Michael Brown  Twenty-five      F  70000.0  123 Main St        NaN
# 3           John Doe      Unknown      M  45000.0  123 Main St     Canada
# 4    Sophia Martinez      Unknown      F      NaN   456 Elm St  Australia
# ..               ...          ...    ...      ...          ...        ...
# 245      Alice Smith           35      F  60000.0  123 Main St     Canada
# 246        Eve Davis  Twenty-five      F      NaN   456 Elm St        USA
# 247    Michael Brown           25      F  60000.0  123 Main St        NaN
# 248    Michael Brown  Twenty-five      M  55000.0  222 Pine St     Canada
# 249      Bob Johnson           40      F  60000.0  123 Main St         UK
#
#       Position  Garbage    Phone Number
# 0      Manager      NaN      4567890123
# 1        Clerk        ?    123-456-7890
# 2      Manager      NaN             NaN
# 3        Clerk      NaN    234-567-8901
# 4       Intern        ?    234-567-8901
# ..         ...      ...             ...
# 245  Developer  Unknown    567-890-1234
# 246    Analyst      NaN    567-890-1234
# 247      Clerk        ?    123-456-7890
# 248    Manager      NaN    234-567-8901
# 249      Clerk  Unknown  (345) 678-9012
#
# [250 rows x 9 columns]

# %%
df.head()
# Out:
#               Name          Age Gender   Salary      Address    Country  \
# 0    Michael Brown      Unknown      F  60000.0      Unknown        USA
# 1      David White           28      F  70000.0   456 Elm St        NaN
# 2    Michael Brown  Twenty-five      F  70000.0  123 Main St        NaN
# 3         John Doe      Unknown      M  45000.0  123 Main St     Canada
# 4  Sophia Martinez      Unknown      F      NaN   456 Elm St  Australia
#
#   Position Garbage  Phone Number
# 0  Manager     NaN    4567890123
# 1    Clerk       ?  123-456-7890
# 2  Manager     NaN           NaN
# 3    Clerk     NaN  234-567-8901
# 4   Intern       ?  234-567-8901

# %%
df.dtypes
# Out:
# Name             object
# Age              object
# Gender           object
# Salary          float64
# Address          object
# Country          object
# Position         object
# Garbage          object
# Phone Number     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          250 non-null    object
#  1   Age           221 non-null    object
#  2   Gender        250 non-null    object
#  3   Salary        185 non-null    float64
#  4   Address       197 non-null    object
#  5   Country       205 non-null    object
#  6   Position      250 non-null    object
#  7   Garbage       103 non-null    object
#  8   Phone Number  178 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 17.7+ KB

# %%
df.describe()
# Out:
#               Salary
# count     185.000000
# mean    66216.216216
# std     25452.572193
# min     45000.000000
# 25%     50000.000000
# 50%     55000.000000
# 75%     70000.000000
# max    120000.000000

# %%
df['Name'].unique()
# Out:
# array(['Michael Brown', 'David White', 'John Doe', 'Sophia Martinez',
#        'Alice Smith', 'Eve Davis', 'Laura Wilson', 'Emma Thomas',
#        'Bob Johnson', 'James Anderson'], dtype=object)

# %%
df['Name'].nunique()
# Out:
# 10

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary', 'Address', 'Country', 'Position',
#        'Garbage', 'Phone Number'],
#       dtype='object')

# %%
for i in df.columns:
  print(i,df[i].unique())
  print('---------------------')
# Out:
# Name ['Michael Brown' 'David White' 'John Doe' 'Sophia Martinez' 'Alice Smith'
#  'Eve Davis' 'Laura Wilson' 'Emma Thomas' 'Bob Johnson' 'James Anderson']
# ---------------------
# Age ['Unknown' '28' 'Twenty-five' '40' '25' '30' nan '35']
# ---------------------
# Gender ['F' 'M']
# ---------------------
# Salary [ 60000.  70000.  45000.     nan 120000.  55000.  50000.]
# ---------------------
# Address ['Unknown' '456 Elm St' '123 Main St' '789 Oak Ave' nan '222 Pine St']
# ---------------------
# Country ['USA' nan 'Canada' 'Australia' 'UK']
# ---------------------
# Position ['Manager' 'Clerk' 'Intern' 'Developer' 'Analyst']
# ---------------------
# Garbage [nan '?' 'Unknown']
# ---------------------
# Phone Number ['4567890123' '123-456-7890' nan '234-567-8901' '(345) 678-9012'
#  '567-890-1234']
# ---------------------

# %%
df.isnull().sum()
# Out:
# Name              0
# Age              29
# Gender            0
# Salary           65
# Address          53
# Country          45
# Position          0
# Garbage         147
# Phone Number     72
# dtype: int64

# %%
df.replace(['?','N/A','Unknown','NaN',''],np.nan, inplace=True)

# %%
for i in df.columns:
  print(i,df[i].unique())
  print('---------------------')
# Out:
# Name ['Michael Brown' 'David White' 'John Doe' 'Sophia Martinez' 'Alice Smith'
#  'Eve Davis' 'Laura Wilson' 'Emma Thomas' 'Bob Johnson' 'James Anderson']
# ---------------------
# Age [nan '28' 'Twenty-five' '40' '25' '30' '35']
# ---------------------
# Gender ['F' 'M']
# ---------------------
# Salary [ 60000.  70000.  45000.     nan 120000.  55000.  50000.]
# ---------------------
# Address [nan '456 Elm St' '123 Main St' '789 Oak Ave' '222 Pine St']
# ---------------------
# Country ['USA' nan 'Canada' 'Australia' 'UK']
# ---------------------
# Position ['Manager' 'Clerk' 'Intern' 'Developer' 'Analyst']
# ---------------------
# Garbage [nan]
# ---------------------
# Phone Number ['4567890123' '123-456-7890' nan '234-567-8901' '(345) 678-9012'
#  '567-890-1234']
# ---------------------

# %%
df
# Out:
#                 Name          Age Gender   Salary      Address    Country  \
# 0      Michael Brown          NaN      F  60000.0          NaN        USA
# 1        David White           28      F  70000.0   456 Elm St        NaN
# 2      Michael Brown  Twenty-five      F  70000.0  123 Main St        NaN
# 3           John Doe          NaN      M  45000.0  123 Main St     Canada
# 4    Sophia Martinez          NaN      F      NaN   456 Elm St  Australia
# ..               ...          ...    ...      ...          ...        ...
# 245      Alice Smith           35      F  60000.0  123 Main St     Canada
# 246        Eve Davis  Twenty-five      F      NaN   456 Elm St        USA
# 247    Michael Brown           25      F  60000.0  123 Main St        NaN
# 248    Michael Brown  Twenty-five      M  55000.0  222 Pine St     Canada
# 249      Bob Johnson           40      F  60000.0  123 Main St         UK
#
#       Position  Garbage    Phone Number
# 0      Manager      NaN      4567890123
# 1        Clerk      NaN    123-456-7890
# 2      Manager      NaN             NaN
# 3        Clerk      NaN    234-567-8901
# 4       Intern      NaN    234-567-8901
# ..         ...      ...             ...
# 245  Developer      NaN    567-890-1234
# 246    Analyst      NaN    567-890-1234
# 247      Clerk      NaN    123-456-7890
# 248    Manager      NaN    234-567-8901
# 249      Clerk      NaN  (345) 678-9012
#
# [250 rows x 9 columns]

# %%
df['Age'].replace(['Twenty-five'],25, inplace=True)

# %%
df
# Out:
#                 Name  Age Gender   Salary      Address    Country   Position  \
# 0      Michael Brown  NaN      F  60000.0          NaN        USA    Manager
# 1        David White   28      F  70000.0   456 Elm St        NaN      Clerk
# 2      Michael Brown   25      F  70000.0  123 Main St        NaN    Manager
# 3           John Doe  NaN      M  45000.0  123 Main St     Canada      Clerk
# 4    Sophia Martinez  NaN      F      NaN   456 Elm St  Australia     Intern
# ..               ...  ...    ...      ...          ...        ...        ...
# 245      Alice Smith   35      F  60000.0  123 Main St     Canada  Developer
# 246        Eve Davis   25      F      NaN   456 Elm St        USA    Analyst
# 247    Michael Brown   25      F  60000.0  123 Main St        NaN      Clerk
# 248    Michael Brown   25      M  55000.0  222 Pine St     Canada    Manager
# 249      Bob Johnson   40      F  60000.0  123 Main St         UK      Clerk
#
#      Garbage    Phone Number
# 0        NaN      4567890123
# 1        NaN    123-456-7890
# 2        NaN             NaN
# 3        NaN    234-567-8901
# 4        NaN    234-567-8901
# ..       ...             ...
# 245      NaN    567-890-1234
# 246      NaN    567-890-1234
# 247      NaN    123-456-7890
# 248      NaN    234-567-8901
# 249      NaN  (345) 678-9012
#
# [250 rows x 9 columns]

# %%
for i in df.columns:
  print(i,df[i].unique())
  print('---------------------')
# Out:
# Name ['Michael Brown' 'David White' 'John Doe' 'Sophia Martinez' 'Alice Smith'
#  'Eve Davis' 'Laura Wilson' 'Emma Thomas' 'Bob Johnson' 'James Anderson']
# ---------------------
# Age [nan '28' 25 '40' '25' '30' '35']
# ---------------------
# Gender ['F' 'M']
# ---------------------
# Salary [ 60000.  70000.  45000.     nan 120000.  55000.  50000.]
# ---------------------
# Address [nan '456 Elm St' '123 Main St' '789 Oak Ave' '222 Pine St']
# ---------------------
# Country ['USA' nan 'Canada' 'Australia' 'UK']
# ---------------------
# Position ['Manager' 'Clerk' 'Intern' 'Developer' 'Analyst']
# ---------------------
# Garbage [nan]
# ---------------------
# Phone Number ['4567890123' '123-456-7890' nan '234-567-8901' '(345) 678-9012'
#  '567-890-1234']
# ---------------------

# %%
df.dtypes
# Out:
# Name             object
# Age              object
# Gender           object
# Salary          float64
# Address          object
# Country          object
# Position         object
# Garbage         float64
# Phone Number     object
# dtype: object

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df.dtypes
# Out:
# Name             object
# Age             float64
# Gender           object
# Salary          float64
# Address          object
# Country          object
# Position         object
# Garbage         float64
# Phone Number     object
# dtype: object

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df['Salary']=pd.to_numeric(df['Salary'], errors='coerce')

# %%
df['Salary'].fillna(df['Salary'].mean(), inplace=True)

# %%
df['Age']=df['Age'].astype(int)

# %%
df['Salary']=df['Salary'].astype(float)

# %%
df.dropna(subset=['Name','Gender'],inplace=True)

# %%
df.columns = df.columns.str.strip()
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St        NaN
# 2      Michael Brown   25      F  70000.000000  123 Main St        NaN
# 3           John Doe   28      M  45000.000000  123 Main St     Canada
# 4    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# ..               ...  ...    ...           ...          ...        ...
# 245      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 246        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 247    Michael Brown   25      F  60000.000000  123 Main St        NaN
# 248    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 249      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position  Garbage    Phone Number
# 0      Manager      NaN      4567890123
# 1        Clerk      NaN    123-456-7890
# 2      Manager      NaN             NaN
# 3        Clerk      NaN    234-567-8901
# 4       Intern      NaN    234-567-8901
# ..         ...      ...             ...
# 245  Developer      NaN    567-890-1234
# 246    Analyst      NaN    567-890-1234
# 247      Clerk      NaN    123-456-7890
# 248    Manager      NaN    234-567-8901
# 249      Clerk      NaN  (345) 678-9012
#
# [250 rows x 9 columns]

# %%
df.loc[df['Salary']>100000, 'Salary'] = np.nan

# %%
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St        NaN
# 2      Michael Brown   25      F  70000.000000  123 Main St        NaN
# 3           John Doe   28      M  45000.000000  123 Main St     Canada
# 4    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# ..               ...  ...    ...           ...          ...        ...
# 245      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 246        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 247    Michael Brown   25      F  60000.000000  123 Main St        NaN
# 248    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 249      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position  Garbage    Phone Number
# 0      Manager      NaN      4567890123
# 1        Clerk      NaN    123-456-7890
# 2      Manager      NaN             NaN
# 3        Clerk      NaN    234-567-8901
# 4       Intern      NaN    234-567-8901
# ..         ...      ...             ...
# 245  Developer      NaN    567-890-1234
# 246    Analyst      NaN    567-890-1234
# 247      Clerk      NaN    123-456-7890
# 248    Manager      NaN    234-567-8901
# 249      Clerk      NaN  (345) 678-9012
#
# [250 rows x 9 columns]

# %%
df['Salary'].fillna(df['Salary'].mean(), inplace=True)

# %%
df['Address'].unique()
# Out:
# array([nan, '456 Elm St', '123 Main St', '789 Oak Ave', '222 Pine St'],
#       dtype=object)

# %%
df['Address'] =df['Address'].str.title()

# %%
df['Address'].unique()
# Out:
# array([nan, '456 Elm St', '123 Main St', '789 Oak Ave', '222 Pine St'],
#       dtype=object)

# %%
df['Gender']=df['Gender'].str.upper()

# %%
df['Country'].fillna('Unknown', inplace=True)

# %%
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St    Unknown
# 2      Michael Brown   25      F  70000.000000  123 Main St    Unknown
# 3           John Doe   28      M  45000.000000  123 Main St     Canada
# 4    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# ..               ...  ...    ...           ...          ...        ...
# 245      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 246        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 247    Michael Brown   25      F  60000.000000  123 Main St    Unknown
# 248    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 249      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position  Garbage    Phone Number
# 0      Manager      NaN      4567890123
# 1        Clerk      NaN    123-456-7890
# 2      Manager      NaN             NaN
# 3        Clerk      NaN    234-567-8901
# 4       Intern      NaN    234-567-8901
# ..         ...      ...             ...
# 245  Developer      NaN    567-890-1234
# 246    Analyst      NaN    567-890-1234
# 247      Clerk      NaN    123-456-7890
# 248    Manager      NaN    234-567-8901
# 249      Clerk      NaN  (345) 678-9012
#
# [250 rows x 9 columns]

# %%
df.drop(columns=['Garbage'], inplace=True)

# %%
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St    Unknown
# 2      Michael Brown   25      F  70000.000000  123 Main St    Unknown
# 3           John Doe   28      M  45000.000000  123 Main St     Canada
# 4    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# ..               ...  ...    ...           ...          ...        ...
# 245      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 246        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 247    Michael Brown   25      F  60000.000000  123 Main St    Unknown
# 248    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 249      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position    Phone Number
# 0      Manager      4567890123
# 1        Clerk    123-456-7890
# 2      Manager             NaN
# 3        Clerk    234-567-8901
# 4       Intern    234-567-8901
# ..         ...             ...
# 245  Developer    567-890-1234
# 246    Analyst    567-890-1234
# 247      Clerk    123-456-7890
# 248    Manager    234-567-8901
# 249      Clerk  (345) 678-9012
#
# [250 rows x 8 columns]

# %%
df['Phone Number'] =df['Phone Number'].str.replace('[^0-9]','',regex=True)
df['Phone Number'] = df['Phone Number'].apply(lambda x: f'{x[:3]}-{x[3:6]}-{x[6:]}' if pd.notnull(x) and len(x)==10 else x )

# %%
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St    Unknown
# 2      Michael Brown   25      F  70000.000000  123 Main St    Unknown
# 3           John Doe   28      M  45000.000000  123 Main St     Canada
# 4    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# ..               ...  ...    ...           ...          ...        ...
# 245      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 246        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 247    Michael Brown   25      F  60000.000000  123 Main St    Unknown
# 248    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 249      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position  Phone Number
# 0      Manager  456-789-0123
# 1        Clerk  123-456-7890
# 2      Manager           NaN
# 3        Clerk  234-567-8901
# 4       Intern  234-567-8901
# ..         ...           ...
# 245  Developer  567-890-1234
# 246    Analyst  567-890-1234
# 247      Clerk  123-456-7890
# 248    Manager  234-567-8901
# 249      Clerk  345-678-9012
#
# [250 rows x 8 columns]

# %%
df = df[df['Phone Number'].str.match(r'^\d{3}-\d{3}-\d{4}$',na=False)]

# %%
df['Position'] =df['Position'].str.title()
# Out:
# <ipython-input-67-f453a552d819>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Position'] =df['Position'].str.title()

# %%
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-68-16cdb8520be8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St    Unknown
# 3           John Doe   28      M  45000.000000  123 Main St     Canada
# 4    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# 5        David White   40      F  58602.986548  123 Main St         UK
# ..               ...  ...    ...           ...          ...        ...
# 245      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 246        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 247    Michael Brown   25      F  60000.000000  123 Main St    Unknown
# 248    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 249      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position  Phone Number
# 0      Manager  456-789-0123
# 1        Clerk  123-456-7890
# 3        Clerk  234-567-8901
# 4       Intern  234-567-8901
# 5    Developer  456-789-0123
# ..         ...           ...
# 245  Developer  567-890-1234
# 246    Analyst  567-890-1234
# 247      Clerk  123-456-7890
# 248    Manager  234-567-8901
# 249      Clerk  345-678-9012
#
# [178 rows x 8 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                 Name  Age Gender        Salary      Address    Country  \
# 0      Michael Brown   28      F  60000.000000          NaN        USA
# 1        David White   28      F  70000.000000   456 Elm St    Unknown
# 2           John Doe   28      M  45000.000000  123 Main St     Canada
# 3    Sophia Martinez   28      F  66216.216216   456 Elm St  Australia
# 4        David White   40      F  58602.986548  123 Main St         UK
# ..               ...  ...    ...           ...          ...        ...
# 173      Alice Smith   35      F  60000.000000  123 Main St     Canada
# 174        Eve Davis   25      F  66216.216216   456 Elm St        USA
# 175    Michael Brown   25      F  60000.000000  123 Main St    Unknown
# 176    Michael Brown   25      M  55000.000000  222 Pine St     Canada
# 177      Bob Johnson   40      F  60000.000000  123 Main St         UK
#
#       Position  Phone Number
# 0      Manager  456-789-0123
# 1        Clerk  123-456-7890
# 2        Clerk  234-567-8901
# 3       Intern  234-567-8901
# 4    Developer  456-789-0123
# ..         ...           ...
# 173  Developer  567-890-1234
# 174    Analyst  567-890-1234
# 175      Clerk  123-456-7890
# 176    Manager  234-567-8901
# 177      Clerk  345-678-9012
#
# [178 rows x 8 columns]

# %%
df.drop_duplicates(subset=['Phone Number'], keep='first', inplace=True)
# Out:
# <ipython-input-72-ff2dd8e09ff4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Phone Number'], keep='first', inplace=True)

# %%
df
# Out:
#             Name  Age Gender        Salary      Address    Country Position  \
# 0  Michael Brown   28      F  60000.000000          NaN        USA  Manager
# 1    David White   28      F  70000.000000   456 Elm St    Unknown    Clerk
# 2       John Doe   28      M  45000.000000  123 Main St     Canada    Clerk
# 8    Alice Smith   30      M  66216.216216          NaN     Canada  Manager
# 9      Eve Davis   28      M  55000.000000          NaN  Australia    Clerk
#
#    Phone Number
# 0  456-789-0123
# 1  123-456-7890
# 2  234-567-8901
# 8  345-678-9012
# 9  567-890-1234

# %%
df.reset_index(drop=True, inplace=True)

# %%
age_upper_limit=df['Age'].quantile(0.99)
df.loc[df['Age']>age_upper_limit, 'Age'] = age_upper_limit
df

# %%
df['Full Address']=df['Address']+','+df['Country']
# Out:
# <ipython-input-76-e54567075d41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Full Address']=df['Address']+','+df['Country']

# %%
df
# Out:
#             Name  Age Gender        Salary      Address    Country Position  \
# 0  Michael Brown   28      F  60000.000000          NaN        USA  Manager
# 1    David White   28      F  70000.000000   456 Elm St    Unknown    Clerk
# 2       John Doe   28      M  45000.000000  123 Main St     Canada    Clerk
# 3    Alice Smith   30      M  66216.216216          NaN     Canada  Manager
# 4      Eve Davis   28      M  55000.000000          NaN  Australia    Clerk
#
#    Phone Number        Full Address
# 0  456-789-0123                 NaN
# 1  123-456-7890  456 Elm St,Unknown
# 2  234-567-8901  123 Main St,Canada
# 3  345-678-9012                 NaN
# 4  567-890-1234                 NaN

# %%
df = df[['Name','Age','Gender','Salary','Address','Country','Position','Phone Number','Full Address']]

# %%
df
# Out:
#             Name  Age Gender        Salary      Address    Country Position  \
# 0  Michael Brown   28      F  60000.000000          NaN        USA  Manager
# 1    David White   28      F  70000.000000   456 Elm St    Unknown    Clerk
# 2       John Doe   28      M  45000.000000  123 Main St     Canada    Clerk
# 3    Alice Smith   30      M  66216.216216          NaN     Canada  Manager
# 4      Eve Davis   28      M  55000.000000          NaN  Australia    Clerk
#
#    Phone Number        Full Address
# 0  456-789-0123                 NaN
# 1  123-456-7890  456 Elm St,Unknown
# 2  234-567-8901  123 Main St,Canada
# 3  345-678-9012                 NaN
# 4  567-890-1234                 NaN
